# %%
import os
os.chdir("C:/Users/User/Desktop/datasets/")  #change the directory to the req location
os.getcwd()
# Out:
# 'C:\\Users\\User\\Desktop\\datasets'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline 
d=pd.read_csv('16Super_Store.csv',header=0,encoding='unicode_escape')
d
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 3          6  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 4         11  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 5         24  US-2017-156909   7/16/2017   7/18/2017    Second Class
# 6         25  CA-2015-106320   9/25/2015   9/30/2015  Standard Class
# 7         28  US-2015-150630   9/17/2015   9/21/2015  Standard Class
# 8         30  US-2015-150630   9/17/2015   9/21/2015  Standard Class
# 9         37  CA-2016-117590   12/8/2016  12/10/2016     First Class
# 10        39  CA-2015-117415  12/27/2015  12/31/2015  Standard Class
# 11        40  CA-2015-117415  12/27/2015  12/31/2015  Standard Class
# 12        52  CA-2015-115742   4/18/2015   4/22/2015  Standard Class
# ...

# %%
d.apply(lambda x:sum(x.isnull()),axis=0)
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
d.corr()
# Out:
#                Row ID  Postal Code     Sales  Quantity  Discount    Profit
# Row ID       1.000000     0.017164  0.001696 -0.000246  0.031848  0.008775
# Postal Code  0.017164     1.000000 -0.011786  0.013700  0.106736 -0.026335
# Sales        0.001696    -0.011786  1.000000  0.437464 -0.028576  0.173510
# Quantity    -0.000246     0.013700  0.437464  1.000000 -0.015695  0.061213
# Discount     0.031848     0.106736 -0.028576 -0.015695  1.000000 -0.483769
# Profit       0.008775    -0.026335  0.173510  0.061213 -0.483769  1.000000

# %%
d.describe()
# Out:
#             Row ID   Postal Code        Sales     Quantity     Discount  \
# count  2121.000000   2121.000000  2121.000000  2121.000000  2121.000000
# mean   5041.643564  55726.556341   349.834887     3.785007     0.173923
# std    2885.740258  32261.888225   503.179145     2.251620     0.181547
# min       1.000000   1040.000000     1.892000     1.000000     0.000000
# 25%    2568.000000  22801.000000    47.040000     2.000000     0.000000
# 50%    5145.000000  60505.000000   182.220000     3.000000     0.200000
# 75%    7534.000000  90032.000000   435.168000     5.000000     0.300000
# max    9991.000000  99301.000000  4416.174000    14.000000     0.700000
#
#             Profit
# count  2121.000000
# mean      8.699327
# std     136.049246
# min   -1862.312400
# 25%     -12.849000
# 50%       7.774800
# 75%      33.726600
# max    1013.127000

# %%
d.boxplot(column='Quantity')

# %%
plt.scatter(d['Quantity'],d['Sales']),d.boxplot(column='Sales',by='Quantity')
# Out:
# (<matplotlib.collections.PathCollection at 0x422e210>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x41bcd10>)

# %%
# when the quantities are less the density of sales are high with the bulk being in low sales values. 
# as the quantity increases though sales decreased,their sale value remained consistent

# since people are interested in buying large quantities of sales consistently...there was no doubt in people remaining quite with these sales,
#       so for a salestore to increase its sales value,if they put these higher valued sales in the first racks of the store
#       people tend to buy more and more higher value sales than the lower valued one's.since the lower valued density is high,
#       it indictes that these are the daily needs.so keeping them in the middle and little back rows doesnot decrease its sales
#                thus,people get their goods needed and the store gets more sales

# %%
plt.scatter(d['Discount'],d['Sales']),d.boxplot(column='Sales',by='Discount')
# Out:
# (<matplotlib.collections.PathCollection at 0x7efbc90>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x422e8b0>)

# %%
# both the sale value and the density of sales were too good when the discount was from 0-20%. but when the discount is more than
#      20% we coulnd see much effect on sales values...and yeah giving dicount more than 40% is just useless.

# %%
plt.scatter(d['Discount'],d['Profit']),plt.scatter(d['Sales'],d['Profit'])
# Out:
# (<matplotlib.collections.PathCollection at 0x7fe4ed0>,
#  <matplotlib.collections.PathCollection at 0x7feb1f0>)

# %%
# the permissible limit for discount is 20%.giving discount more than 20% land the store in losses.

# %%
plt.scatter(d['Discount'],d['Quantity'])

# %%
# even with 20% and less discounts,the quantity of sales were quite incremental...and we have already seen that these are the 
#       daily needs.
# we can see a consistent increament in quantities with discounts upto 40%.but,for higher discounts 
#       the limit isnt crossing quantity 9.
# thus a potential can be expected by giving combos of lower sales goods with higher sales goods as combos with discounts of 30%, 
#       so that we need not give
#       discounts lo lower sale value goods(needs) and more no of higher sale goods increases.this also implies that when we 
#       give less of lower sales valued goods in combos,there is a need for more quantities to be bought w.r.to lower sale items
#       so definitely they will again buy lowe sale goods but now with no discounts and less quantities as they already got 
#       some quantities in combos.

# we can also give decent discounts for medium range values

# %%
plt.scatter(d['Sales'],d['Profit'])

# %%
# sales more than 1000 have less -ve profits

# %%
plt.scatter(d['Ship Mode'],d['Profit']),d.boxplot(column='Profit',by='Ship Mode')
# Out:
# (<matplotlib.collections.PathCollection at 0x8170b50>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x8170b90>)

# %%
plt.scatter(d['Segment'],d['Profit']),d.boxplot(column='Profit',by='Segment')
# Out:
# (<matplotlib.collections.PathCollection at 0x800a5b0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x8200f10>)

# %%
plt.scatter(d['Region'],d['Profit']),plt.scatter(d['Sub-Category'],d['Profit'])
# Out:
# (<matplotlib.collections.PathCollection at 0x81dccd0>,
#  <matplotlib.collections.PathCollection at 0x8097450>)

# %%
d['Country'].value_counts()
# Out:
# United States    2121
# Name: Country, dtype: int64

# %%
d.boxplot(column='Profit',by='Sales')

# %%
import seaborn as sns
sns.distplot(d['Profit'])

# %%
sns.distplot(d['Discount'])

# %%
sns.distplot(d['Quantity'])

# %%
sns.distplot(d['Sales'])

# %%
corr=d.corr()
sns.heatmap(corr,xticklabels=corr.columns,yticklabels=corr.columns)

# %%
mean_of_Profits=d['Profit'].mean()
plt.plot(d['Sales'],d['Profit'],'o')     # 'o' is the plot style...to see bubble like points
plt.ylabel('Profit')
plt.xlabel('Sales')
plt.axhline(mean_of_Profits,color='r',linestyle='-')
sns.regplot(x='Sales',y='Profit',data=d)
